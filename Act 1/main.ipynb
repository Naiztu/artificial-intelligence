# %% [markdown]
# # Activity 2.1 Generation or selection of the data set

# %% [markdown]
# **José Ángel Rico Mendieta - A01707404**

# %% [markdown]
# ## Get, generate or increase a data set

# %% [markdown]
# ### Data set selected - Music features
# #### About Dataset
# ##### Context
# A music genre is a conventional category that identifies pieces of music as belonging to a shared tradition or set of conventions. It is to be distinguished from musical form and musical style. The features extracted from these waves can help the machine distinguish between them.
#
# ##### Content
# The features in this dataset are extracted from the dataset provided [here](http://marsyas.info/) which consists of 1000 audio tracks each 30 seconds long. It contains 10 genres, each represented by 100 tracks. The tracks are all 22050Hz Mono 16-bit audio files in .wav format. The code used to extract features is at this GitHub repo. Features are extracted using [libROSA](https://librosa.github.io/librosa/) library.
#
# ##### Acknowledgements
# The credits to this dataset go to [MARSYAS](http://marsyas.info/).
#
# ##### Inspiration
# Due to the artistic nature of music, the classifications are often arbitrary and controversial, and some genres may overlap. Train a model and know to which genre your favourite piece of music belong to.

# %%
import pandas as pd

# %%
ruta = './'
df = pd.read_csv(ruta+'data.csv')

# %%
df
# Out:
#            filename       tempo  beats  chroma_stft      rmse  \
# 0    blues.00081.au  103.359375     50     0.380260  0.248262
# 1    blues.00022.au   95.703125     44     0.306451  0.113475
# 2    blues.00031.au  151.999081     75     0.253487  0.151571
# 3    blues.00012.au  184.570312     91     0.269320  0.119072
# 4    blues.00056.au  161.499023     74     0.391059  0.137728
# ..              ...         ...    ...          ...       ...
# 995   rock.00017.au  123.046875     59     0.418812  0.166056
# 996   rock.00081.au  117.453835     56     0.335774  0.093676
# 997   rock.00004.au  103.359375     45     0.372834  0.208743
# 998   rock.00006.au  112.347147     45     0.344472  0.180163
# 999   rock.00066.au   75.999540     36     0.360098  0.042995
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 0          2116.942959         1956.611056  4196.107960            0.127272
# 1          1156.070496         1497.668176  2170.053545            0.058613
# 2          1331.073970         1973.643437  2900.174130            0.042967
# 3          1361.045467         1567.804596  2739.625101            0.069124
# 4          1811.076084         2052.332563  3927.809582            0.075480
# ..                 ...                 ...          ...                 ...
# 995        2312.030070         2060.825761  4528.197619            0.140588
# 996        2553.856706         2219.090892  5123.752351            0.136173
# 997        1345.850763         1841.748033  2939.265560            0.041099
# 998        1675.475369         1653.422860  3253.563659            0.087294
# 999        2209.357588         2175.214294  4575.588999            0.107147
#
#           mfcc1  ...     mfcc12     mfcc13    mfcc14    mfcc15    mfcc16  \
# 0    -26.929785  ...  14.336612 -13.821769  7.562789 -6.181372  0.330165
# 1   -233.860772  ...  -2.250578   3.959198  5.322555  0.812028 -1.107202
# 2   -221.802549  ... -13.037723 -12.652228 -1.821905 -7.260097 -6.660252
# 3   -207.208080  ...  -0.613248   0.384877  2.605128 -5.188924 -9.527455
# 4   -145.434568  ...   7.457218 -10.470444 -2.360483 -6.783623  2.671134
# ..          ...  ...        ...        ...       ...       ...       ...
# 995  -41.402023  ...  11.303100 -14.155566  2.824157 -9.477822  3.331261
# 996 -121.410791  ...   9.149520 -10.112054  4.211237 -9.349345  1.609701
# 997 -127.946876  ...  11.043714  -8.385375  2.111019 -6.338260  0.997383
# 998  -98.356322  ...   2.945863 -12.509212  0.091337 -0.774780 -5.700102
# 999 -245.160921  ...   0.813777 -13.018359  0.053168 -8.232851  1.059255
#
#         mfcc17     mfcc18     mfcc19     mfcc20  label
# 0    -6.829571   0.965922  -7.570825   2.918987  blues
# 1    -4.556555  -2.436490   3.316913  -0.608485  blues
# 2   -14.682694 -11.719264 -11.025216 -13.387260  blues
# 3    -9.244394  -2.848274  -1.418707  -5.932607  blues
# 4    -4.760879  -0.949005   0.024832  -2.005315  blues
# ..         ...        ...        ...        ...    ...
# 995  -8.200088   3.693091  -3.673562  -0.163201   rock
# 996 -10.553566   1.066489  -1.654875   7.544224   rock
# 997  -5.325869  -0.842192  -4.665996  -4.787677   rock
# 998  -8.630916  -1.903803  -2.196753  -3.395148   rock
# 999  -8.031864  -0.397097  -4.349921  -4.220998   rock
#
# [1000 rows x 30 columns]

# %%
df.describe()
# Out:
#              tempo        beats  chroma_stft         rmse  spectral_centroid  \
# count  1000.000000  1000.000000  1000.000000  1000.000000        1000.000000
# mean    119.601702    57.138000     0.378656     0.130929        2201.834226
# std      28.297367    14.225728     0.081689     0.065685         715.961347
# min      54.978391    18.000000     0.171782     0.005276         569.930721
# 25%      99.384014    47.000000     0.319641     0.086625        1627.793931
# 50%     117.453835    56.000000     0.383075     0.122448        2209.468780
# 75%     135.999178    65.250000     0.435974     0.175793        2691.969702
# max     234.907670   117.000000     0.663573     0.398012        4434.439444
#
#        spectral_bandwidth      rolloff  zero_crossing_rate        mfcc1  \
# count         1000.000000  1000.000000         1000.000000  1000.000000
# mean          2242.559613  4571.702159            0.103637  -144.479173
# std            526.337663  1574.770035            0.041834   100.235661
# min            897.994319   749.062137            0.021701  -552.064063
# 25%           1907.136505  3380.956639            0.070281  -200.695133
# 50%           2221.408983  4658.671830            0.099539  -120.206072
# 75%           2578.474352  5534.197785            0.132007   -73.895019
# max           3509.578677  8676.405868            0.274829    42.034587
#
#              mfcc2  ...       mfcc11       mfcc12       mfcc13       mfcc14  \
# count  1000.000000  ...  1000.000000  1000.000000  1000.000000  1000.000000
# mean     99.552199  ...    -6.021121     4.471604    -4.797232     1.781547
# std      31.331904  ...     6.819018     6.717312     6.170919     5.009489
# min      -1.527148  ...   -28.052265   -15.805227   -27.542309   -12.598773
# 25%      76.811480  ...   -10.966826    -0.551576    -9.363372    -1.640080
# 50%      98.452551  ...    -5.920161     3.891842    -4.199810     1.879424
# 75%     119.893638  ...    -1.004241     9.706133    -0.161017     5.155264
# max     193.096518  ...    17.421038    23.037571    13.054333    18.161663
#
#             mfcc15       mfcc16       mfcc17       mfcc18       mfcc19  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -3.870275     1.147988    -3.967431     0.507303    -2.328779
# std       4.874423     4.579110     4.550650     3.869088     3.755574
# min     -17.545474   -15.693589   -17.227765   -11.975698   -18.504188
# 25%      -7.164838    -1.857098    -7.194297    -2.003979    -4.670281
# 50%      -3.614473     1.211944    -4.059109     0.669788    -2.391261
# 75%      -0.323536     4.350694    -0.842968     3.112518     0.149070
# max      12.357588    13.468803    11.489994    15.379257    14.686910
#
#             mfcc20
# count  1000.000000
# mean     -1.094875
# std       3.837561
# min     -19.935203
# 25%      -3.368000
# 50%      -1.155198
# 75%       1.303739
# max      15.368966
#
# [8 rows x 28 columns]

# %%
df.groupby('label').count()
# Out:
#            filename  tempo  beats  chroma_stft  rmse  spectral_centroid  \
# label
# blues           100    100    100          100   100                100
# classical       100    100    100          100   100                100
# country         100    100    100          100   100                100
# disco           100    100    100          100   100                100
# hiphop          100    100    100          100   100                100
# jazz            100    100    100          100   100                100
# metal           100    100    100          100   100                100
# pop             100    100    100          100   100                100
# reggae          100    100    100          100   100                100
# rock            100    100    100          100   100                100
#
#            spectral_bandwidth  rolloff  zero_crossing_rate  mfcc1  ...  \
# label                                                              ...
# blues                     100      100                 100    100  ...
# classical                 100      100                 100    100  ...
# country                   100      100                 100    100  ...
# disco                     100      100                 100    100  ...
# hiphop                    100      100                 100    100  ...
# jazz                      100      100                 100    100  ...
# metal                     100      100                 100    100  ...
# pop                       100      100                 100    100  ...
# reggae                    100      100                 100    100  ...
# rock                      100      100                 100    100  ...
#
#            mfcc11  mfcc12  mfcc13  mfcc14  mfcc15  mfcc16  mfcc17  mfcc18  \
# label
# blues         100     100     100     100     100     100     100     100
# classical     100     100     100     100     100     100     100     100
# country       100     100     100     100     100     100     100     100
# disco         100     100     100     100     100     100     100     100
# hiphop        100     100     100     100     100     100     100     100
# jazz          100     100     100     100     100     100     100     100
# metal         100     100     100     100     100     100     100     100
# pop           100     100     100     100     100     100     100     100
# reggae        100     100     100     100     100     100     100     100
# rock          100     100     100     100     100     100     100     100
#
#            mfcc19  mfcc20
# label
# blues         100     100
# classical     100     100
# country       100     100
# disco         100     100
# hiphop        100     100
# jazz          100     100
# metal         100     100
# pop           100     100
# reggae        100     100
# rock          100     100
#
# [10 rows x 29 columns]

# %%
import matplotlib.pyplot as plt

labels = df['label'].unique()
counts = df.groupby('label').count().iloc[:, 0].values

plt.bar(labels, counts)

plt.title('Number of Labels')
plt.xlabel('Labels')
plt.ylabel('Counts')
plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ## Make the separation of test and training sets.

# %%
from sklearn.model_selection import train_test_split

train_df, test_df = train_test_split(df, test_size=0.2)
train_df, val_df = train_test_split(train_df, test_size=0.1)

# %%
train_df
# Out:
#                filename       tempo  beats  chroma_stft      rmse  \
# 224    country.00075.au   95.703125     45     0.371812  0.179790
# 728        pop.00074.au   83.354335     40     0.349401  0.210437
# 745        pop.00073.au  129.199219     63     0.423459  0.259874
# 409     hiphop.00056.au   99.384014     48     0.491684  0.166681
# 653      metal.00002.au  112.347147     55     0.432488  0.132800
# ..                  ...         ...    ...          ...       ...
# 326      disco.00017.au  123.046875     58     0.404680  0.116156
# 330      disco.00031.au  123.046875     60     0.417187  0.115771
# 119  classical.00043.au  129.199219     55     0.190957  0.115408
# 354      disco.00049.au  123.046875     59     0.421386  0.209587
# 773        pop.00085.au  117.453835     55     0.443711  0.195365
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 224        2187.471351         2242.244357  4841.754056            0.113754
# 728        3419.368447         3368.739507  7789.127900            0.130848
# 745        3671.164313         3295.563300  7879.035690            0.161897
# 409        2355.472334         2496.918194  5176.660364            0.070130
# 653        2198.534549         2005.997790  4446.439780            0.128393
# ..                 ...                 ...          ...                 ...
# 326        2564.559468         2670.214278  5388.834081            0.120760
# 330        3257.059829         2898.058255  6680.934601            0.173815
# 119        1063.153306         1552.089040  1610.948592            0.051041
# 354        2397.106366         2208.666121  4920.761911            0.135321
# 773        2516.610746         2465.673109  5087.469237            0.122096
#
#           mfcc1  ...     mfcc12     mfcc13    mfcc14     mfcc15    mfcc16  \
# 224  -60.820160  ...  13.190665 -12.202099  2.353400 -12.198769  6.439695
# 728  -93.615151  ...   2.674555  -3.085624 -5.751635  -1.518938 -1.188848
# 745   -8.508436  ...   0.871044  -1.940017 -2.784899  -2.675063 -3.317282
# 409 -101.056764  ...   9.902102   2.935303 -3.001592  -1.243675  2.309615
# 653  -62.183622  ...   9.662311 -14.543764  6.927252  -7.479272  5.968114
# ..          ...  ...        ...        ...       ...        ...       ...
# 326  -98.128867  ...  -5.485744  -4.233684 -3.770910  -1.715215 -5.583503
# 330  -66.537546  ...  -3.735936  -3.238142 -1.327639  -3.433793 -1.188312
# 119 -249.533810  ...  -7.175682  -7.889322 -2.082100  -2.908614 -0.859944
# 354  -45.101250  ...   8.132065 -11.932609  5.366526  -7.677786  3.676450
# 773  -81.770638  ...   4.658123   2.407110  5.516882   0.622460 -1.800066
#
#        mfcc17    mfcc18    mfcc19    mfcc20      label
# 224 -1.783286  6.332672 -1.332245 -2.794573    country
# 728 -3.051285 -1.085782  2.389741  4.761807        pop
# 745  1.705886 -0.149544  4.846445  2.909008        pop
# 409 -2.814028  1.758978  0.858977 -4.347203     hiphop
# 653 -3.471041  6.574543 -6.574576  2.961322      metal
# ..        ...       ...       ...       ...        ...
# 326 -4.686110 -2.706112 -1.840375 -3.091555      disco
# 330 -4.383120 -3.655099 -2.085793 -0.304350      disco
# 119 -3.972878 -0.883545 -3.987475 -3.885225  classical
# 354 -6.798335  1.482898 -5.800611 -2.507354      disco
# 773  2.316440  7.857251  5.020962 -3.324792        pop
#
# [720 rows x 30 columns]

# %%
test_df
# Out:
#                filename       tempo  beats  chroma_stft      rmse  \
# 177  classical.00038.au  151.999081     59     0.294410  0.044319
# 118  classical.00036.au  107.666016     48     0.239282  0.016010
# 12       blues.00040.au  172.265625     83     0.397725  0.134892
# 276    country.00078.au   66.256010     31     0.376450  0.043278
# 298    country.00038.au  151.999081     76     0.367296  0.090958
# ..                  ...         ...    ...          ...       ...
# 129  classical.00099.au   95.703125     45     0.333863  0.010503
# 879     reggae.00050.au   95.703125     46     0.460109  0.131103
# 604      metal.00012.au  172.265625     81     0.605022  0.114323
# 582       jazz.00046.au  107.666016     51     0.250240  0.110548
# 141  classical.00004.au  161.499023     80     0.223171  0.042300
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 177        1279.041661         1339.072399  2376.660629            0.075836
# 118        1281.770846         1502.895726  2440.360243            0.059410
# 12         2272.495079         2356.855937  5108.319111            0.097657
# 276        1143.784023         1443.360893  2221.644899            0.049858
# 298        2860.295766         2919.888398  6247.020558            0.121158
# ..                 ...                 ...          ...                 ...
# 129        1524.906761         1868.921918  3325.104894            0.080683
# 879        2955.744714         2690.531717  5870.956166            0.127109
# 604        2803.257355         2183.197655  5262.659844            0.176913
# 582        1295.167919         1446.061103  2695.342035            0.058650
# 141        1705.704611         1646.292971  3175.739130            0.112867
#
#           mfcc1  ...     mfcc12     mfcc13     mfcc14     mfcc15    mfcc16  \
# 177 -276.043356  ...  -4.190682  -1.677291  -1.520687  -3.197954 -1.768454
# 118 -419.228897  ...  -5.439006  -9.099890 -10.616878  -5.737675 -0.392487
# 12  -110.260079  ...   5.952405  -8.033586   4.239868 -16.485552  6.542503
# 276 -302.562904  ...   7.889340   1.328553   0.480184   0.081418 -3.203777
# 298 -118.013918  ...  -1.122174   2.441451  -1.423066  -4.742861 -6.376284
# ..          ...  ...        ...        ...        ...        ...       ...
# 129 -378.724476  ...  18.226380 -10.275831   8.955647   1.210981  6.280481
# 879 -104.857367  ...   4.585059   4.210013   3.100181  -1.413896  0.227106
# 604  -64.086452  ...  17.917866 -10.794271  11.355470 -11.166484  8.714769
# 582 -204.188148  ...   1.565304   1.477296  -2.724842  -0.284619 -2.217541
# 141 -259.909976  ...  -1.196833  -6.347265   2.761452  -2.592574  4.384807
#
#        mfcc17    mfcc18    mfcc19    mfcc20      label
# 177 -2.238901 -3.524319 -2.994683 -3.303549  classical
# 118  7.027567  5.593974 -3.469120 -5.166213  classical
# 12  -5.695943 -3.640864 -4.856884  1.854516      blues
# 276 -1.829369  0.876499  0.578183 -3.153038    country
# 298 -5.753704 -6.265547 -4.510278 -1.000420    country
# ..        ...       ...       ...       ...        ...
# 129  2.530584  4.389195  1.705061  9.986726  classical
# 879  1.094144 -2.326807 -2.894488 -2.185389     reggae
# 604 -8.964144  3.227732 -5.749997  2.419906      metal
# 582  1.517983 -1.054650 -1.772528 -2.468121       jazz
# 141 -4.136895 -4.779474 -4.772360 -4.608322  classical
#
# [200 rows x 30 columns]

# %%
val_df
# Out:
#             filename       tempo  beats  chroma_stft      rmse  \
# 900    rock.00019.au  117.453835     58     0.435911  0.112228
# 73    blues.00024.au  103.359375     51     0.263129  0.086982
# 594    jazz.00085.au   80.749512     38     0.325405  0.071399
# 315   disco.00029.au  103.359375     52     0.384024  0.147585
# 885  reggae.00017.au  129.199219     61     0.425863  0.139735
# ..               ...         ...    ...          ...       ...
# 366   disco.00039.au  112.347147     54     0.340977  0.124363
# 994    rock.00075.au  117.453835     59     0.408572  0.126917
# 340   disco.00034.au  129.199219     63     0.357579  0.122907
# 704     pop.00037.au  103.359375     51     0.451668  0.240985
# 922    rock.00078.au   99.384014     48     0.358033  0.144444
#
#      spectral_centroid  spectral_bandwidth      rolloff  zero_crossing_rate  \
# 900        2321.185733         2118.985282  4702.063234            0.128200
# 73         1120.387619         1447.839934  2325.102607            0.047298
# 594        2861.040477         2566.590601  5606.299433            0.147577
# 315        3074.955857         3031.864321  6848.700254            0.138534
# 885        1803.468087         1973.146839  3777.160493            0.077965
# ..                 ...                 ...          ...                 ...
# 366        2328.613340         2431.945152  4868.128896            0.101186
# 994        2301.761135         2355.225614  5092.235875            0.111545
# 340        3653.421307         3234.175702  7835.319288            0.180835
# 704        3236.413205         2953.596262  6698.776160            0.164825
# 922        1878.740319         2204.944115  4287.182409            0.071730
#
#           mfcc1  ...    mfcc12     mfcc13    mfcc14    mfcc15    mfcc16  \
# 900  -84.179579  ...  5.228019 -16.757764  1.092846 -9.666018  1.088416
# 73  -274.288785  ...  0.080915  -0.939682  2.295373  4.290512 -1.661926
# 594 -131.907555  ...  3.422568  -2.887963  3.226356 -1.340070  0.873017
# 315  -58.983572  ... -0.311374  -2.834166 -8.802202 -4.489741 -6.410673
# 885 -154.911898  ...  8.884952  -6.708203  6.013780 -2.792921  3.635893
# ..          ...  ...       ...        ...       ...       ...       ...
# 366 -107.363727  ... -3.855222  -2.579959 -0.903760  7.029755  3.783826
# 994 -113.668423  ...  9.968235 -13.467302  7.566163 -7.262604  3.633977
# 340  -65.764855  ... -1.887074  -7.244224 -5.266682 -3.038180 -4.335730
# 704    4.821123  ...  1.753352   3.336132  2.352307  1.428845 -0.604926
# 922 -131.050567  ...  9.195827  -6.963253  6.312278 -9.626780  0.505373
#
#         mfcc17    mfcc18    mfcc19    mfcc20   label
# 900  -7.537925  3.236286 -4.712544 -0.318536    rock
# 73  -10.444825 -6.797826 -1.068164 -1.596130   blues
# 594   3.681538  0.637190 -0.369353  6.323373    jazz
# 315   0.460101 -2.270874  2.979138 -0.015528   disco
# 885  -2.212498  5.290565 -6.594642 -2.934966  reggae
# ..         ...       ...       ...       ...     ...
# 366   3.345733  5.202933  2.875051  3.182482   disco
# 994  -8.458357  0.392575 -9.224973 -0.279239    rock
# 340  -2.541413  0.725952 -0.304219  2.940630   disco
# 704  -2.185691 -1.602394 -0.612146 -4.050126     pop
# 922 -12.774694 -4.904711 -2.517013 -3.125298    rock
#
# [80 rows x 30 columns]
